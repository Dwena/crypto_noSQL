# %%
from pprint import pprint as pp
import pymongo
from pymongo import MongoClient
import json
import pandas as pd
import certifi
import API.db_connection as database

ca = certifi.where()

# %%
client = pymongo.MongoClient("mongodb+srv://CryptoIpssi:jL6CFlCdNzKiQPoT@cryptocluster0.azkufll.mongodb.net/?retryWrites=true&w=majority", tlsCAFile=ca)
dba = client.CryptoData

# %%
dba.list_collection_names()
list(dba.coins.find())
# Out:
# [{'_id': ObjectId('63ff185951ab1e8f3c1b9044'),
#   'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 23846,
#   'market_cap': 458952812557,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 499252601413,
#   'total_volume': 30934398904,
#   'high_24h': 23884,
#   'low_24h': 23063,
#   'price_change_24h': 508.34,
#   'price_change_percentage_24h': 2.17816,
#   'market_cap_change_24h': 9501331751,
#   'market_cap_change_percentage_24h': 2.11398,
#   'circulating_supply': 19304875.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -65.45645,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 35073.08407,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-03-01T09:15:08.580Z'},
#  {'_id': ObjectId('63ff185951ab1e8f3c1b9045'),
# ...

# %%
db=database.Database()
db.get_collections()
# Out:
# currency
# coins

# %%
db.get_one_coin( "bitcoin" )
# Out:
# [{'_id': ObjectId('63ff185951ab1e8f3c1b9044'),
#   'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 23846,
#   'market_cap': 458952812557,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 499252601413,
#   'total_volume': 30934398904,
#   'high_24h': 23884,
#   'low_24h': 23063,
#   'price_change_24h': 508.34,
#   'price_change_percentage_24h': 2.17816,
#   'market_cap_change_24h': 9501331751,
#   'market_cap_change_percentage_24h': 2.11398,
#   'circulating_supply': 19304875.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -65.45645,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 35073.08407,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-03-01T09:15:08.580Z'}]

# %%
db.get_all_coins()
# Out:
# [{'_id': ObjectId('63ff23cf186d8f7d51695856'),
#   'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 23756,
#   'market_cap': 459010632065,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 499314540951,
#   'total_volume': 31471342039,
#   'high_24h': 23884,
#   'low_24h': 23063,
#   'price_change_24h': 484.81,
#   'price_change_percentage_24h': 2.08326,
#   'market_cap_change_24h': 9513020303,
#   'market_cap_change_percentage_24h': 2.11637,
#   'circulating_supply': 19304912.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -65.56125,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 34966.36662,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-03-01T10:05:48.192Z'},
#  {'_id': ObjectId('63ff23cf186d8f7d51695857'),
# ...
